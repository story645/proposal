# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt

import data
import channels
import artists

# %%
table = data.Section().table()

# %%
cmap = {'true':'green', 'false':'red'}
transforms = {'y': ('v1', channels.Position()),       
              'x': ('v2', channels.Position()),
            'facecolors': ('v3', channels.NominalColor(cmap))}

# %%
fig, ax = plt.subplots()

artist = artists.Point(table, transforms)
ax.add_artist(artist)
ax.set(xlim = (table.F[transforms['x'][0]].min, 
               table.F[transforms['x'][0]].max), 
       ylim = (table.F[transforms['y'][0]].min, 
               table.F[transforms['y'][0]].max),       
       xlabel = transforms['x'][0], 
       ylabel = transforms['y'][0], 
       aspect='equal')
# Out:
# [(0.0, 10.0), (1.0, 5.0), Text(0.5, 0, 'v2'), Text(0, 0.5, 'v1'), None]

# %%
fig, ax = plt.subplots()

artist = artists.Line(table, transforms)
ax.add_artist(artist)
ax.set(xlim = (table.F[transforms['x'][0]].min, 
               table.F[transforms['x'][0]].max), 
       ylim = (table.F[transforms['y'][0]].min, 
               table.F[transforms['y'][0]].max),       
       xlabel = transforms['x'][0], 
       ylabel = transforms['y'][0], 
       aspect='equal')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-ec6a5ddfb08a> in <module>
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 artist = artists.Line(table, transforms)
#       4 ax.add_artist(artist)
#       5 ax.set(xlim = (table.F[transforms['x'][0]].min,
#
# c:\Users\story\Projects\proposal\code\matplottoy\artists.py in __init__(self, data, transforms, *args, **kwargs)
#      60         """
#      61         super().__init__(None, *args, **kwargs)
# ---> 62         assert data.K['ndims'] == 1
#      63
#      64         assert Line.required <= transforms.keys()
#
# AssertionError:

# %%
table_1d = data.Section().table()
table_1d.K['ndims'] = 1

# %%
transforms_1d = {'y': ('v1', channels.Position()),       
                 'x': ('v2', channels.Position())}

# %%
fig, ax = plt.subplots()

artist = artists.Line(table_1d, transforms_1d)
ax.add_artist(artist)
ax.set(xlim = (table_1d.F[transforms_1d['x'][0]].min, 
               table_1d.F[transforms_1d['x'][0]].max), 
       ylim = (table_1d.F[transforms_1d['y'][0]].min, 
               table_1d.F[transforms_1d['y'][0]].max),       
       xlabel = transforms_1d['x'][0], 
       ylabel = transforms_1d['y'][0], 
       aspect='equal')

# %%
  visual = dict([(t, tau.convert(table_1d.view()[var]))
            for (t, (var, tau)) in transforms_1d.items()])

# %%
segments = np.vstack([visual['x'], visual['y']]).T

# %%
segments.shape
# Out:
# (1000, 2)

# %%
import matplotlib.cbook as mcbook

# %%
mcbook._check_shape((None, 2), vertices=segments)
